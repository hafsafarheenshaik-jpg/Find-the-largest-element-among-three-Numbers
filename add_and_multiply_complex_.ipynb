# %%
n1 = complex(input("Enter the first complex number : "))
n2 = complex(input("Enter the second complex number: "))

# Addition
addition = n1 + n2

# Multiplication
multiplication = n1 * n2

print("Addition of complex numbers =", addition)
print("Multiplication of complex numbers =", multiplication)
# Out:
# Enter the first complex number : 5+2j
# Enter the second complex number: 2+5j
# Addition of complex numbers = (7+7j)
# Multiplication of complex numbers = 29j
